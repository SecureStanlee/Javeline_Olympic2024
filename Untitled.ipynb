# %%
import pandas as pd

# %%
df=pd.read_csv('olympic_javelinedata.csv')

# %%
df.head()
# Out:
#    Angle  Speed   Range  Projectile_Range
# 0  31.79   100.9   82.3             71.79
# 1  34.51   105.1   84.9             81.21
# 2  33.01   108.1   88.5             84.07
# 3  30.77   105.3   79.4             76.75
# 4  32.57   107.8   87.4             83.02

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(df['Range'], color="blue", label="Range")  # Label added
plt.plot(df['Projectile_Range'], color="red", label="Projectile Range")

# %%
plt.plot(df['Range'], color="blue", label="On ground Range")  # Label added
plt.plot(df['Projectile_Range'], color="red", label="Calc. Range")  # Label added

# Adding titles and labels
plt.title("Science vs Real_life")
# plt.xlabel("Index")
plt.ylabel("Ranges")

# Adding a legend to the plot
plt.legend()

# Display the plot
plt.show()
